# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Define the parameters for the radar chart
labels = ['Data Privacy', 'Security', 'Ethical Concerns', 'Accuracy', 'Regulatory Compliance', 'Operational Risk']
values = [4, 3, 4, 5, 3, 2]  # Example values for the chart (scale of 1 to 5)

# Number of variables
num_vars = len(labels)

# Compute angle of each axis
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The radar chart is a circle, so we need to "close" the circle by repeating the first value at the end
values += values[:1]
angles += angles[:1]

# Create the radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='blue', alpha=0.25)
ax.plot(angles, values, color='blue', linewidth=2)  # Outline of the chart
ax.set_yticklabels([])  # Remove radial labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=12, color='black')

# Style adjustments to make it look minimalist
ax.spines['polar'].set_visible(False)  # Hide the frame
ax.grid(linewidth=0.5, linestyle='-', color='black', alpha=0.3)  # Lighter grid lines

# Title
plt.title('GPT Application Risk Assessment', fontsize=14, color='black', va='bottom')

# Add full citation as text on the chart with title and author
citation_text = ( "Radar Chart")


# Add citations at the bottom of the chart, make sure they fit into multiple lines
plt.figtext(0.5, 0.05, citation_text, wrap=True, horizontalalignment='center', fontsize=10, color='black')

file_path = 'gpt_application_risk_assessment.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the chart
plt.show()

file_path

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Define the parameters for the radar chart
labels = ['Data Privacy', 'Security', 'Ethical Concerns', 'Accuracy', 'Regulatory Compliance', 'Operational Risk']
values = [4, 3, 4, 5, 3, 2]  # Example values for the chart (scale of 1 to 5)

# Number of variables
num_vars = len(labels)

# Compute angle of each axis
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The radar chart is a circle, so we need to "close" the circle by repeating the first value at the end
values += values[:1]
angles += angles[:1]

# Create the radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='blue', alpha=0.25)
ax.plot(angles, values, color='blue', linewidth=2)  # Outline of the chart
ax.set_yticklabels([])  # Remove radial labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=12, color='black')

# Style adjustments to make it look minimalist
ax.spines['polar'].set_visible(False)  # Hide the frame
ax.grid(linewidth=0.5, linestyle='-', color='black', alpha=0.3)  # Lighter grid lines

# Title
plt.title('GPT Application Risk Assessment', fontsize=14, color='black', va='bottom')

# Add full citations as text on the chart with title and author
citation_text = ( "Radar Chart")
# Add citations at the bottom of the chart, make sure they fit into multiple lines
plt.figtext(0.5, 0.05, citation_text, wrap=True, horizontalalignment='center', fontsize=10, color='black')

# Save the chart as a PNG file
file_path = 'gpt_application_risk_assessment_radar_with_full_citations_finance_papers.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the chart
plt.show()

file_path

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Define the parameters for the radar chart with new axes
labels = ['Model Performance', 'Ethical Considerations', 'Security', 'Regulatory Compliance', 'Scalability', 'Deployment Efficiency']
values = [4, 3, 5, 3, 4, 4]  # Example values for the chart (scale of 1 to 5)

# Number of variables
num_vars = len(labels)

# Compute angle of each axis
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The radar chart is a circle, so we need to "close" the circle by repeating the first value at the end
values += values[:1]
angles += angles[:1]

# Create the radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='green', alpha=0.25)
ax.plot(angles, values, color='green', linewidth=2)  # Outline of the chart
ax.set_yticklabels([])  # Remove radial labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=12, color='black')

# Style adjustments to make it look minimalist
ax.spines['polar'].set_visible(False)  # Hide the frame
ax.grid(linewidth=0.5, linestyle='-', color='black', alpha=0.3)  # Lighter grid lines

# Title
plt.title('Generative AI in Financial Services Risk Assessment', fontsize=14, color='black', va='bottom')

# Add full citations as text on the chart with title and author
citation_text = ( "radar Chart")

# Add citations at the bottom of the chart, make sure they fit into multiple lines
plt.figtext(0.5, 0.05, citation_text, wrap=True, horizontalalignment='center', fontsize=10, color='black')

# Save the chart as a PNG file
file_path = 'generative_ai_in_financial_services_risk_assessment_radar_with_citations.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the chart
plt.show()

file_path

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Define the new parameters for the radar chart with creative axes
labels = ['AI Integration', 'Innovation Potential', 'Cost Efficiency', 'Customer Experience', 'Data Utilization', 'Adoption Speed']
values = [4, 5, 3, 4, 5, 3]  # Example values for the chart (scale of 1 to 5)

# Number of variables
num_vars = len(labels)

# Compute angle of each axis
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()

# The radar chart is a circle, so we need to "close" the circle by repeating the first value at the end
values += values[:1]
angles += angles[:1]

# Create the radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='purple', alpha=0.25)
ax.plot(angles, values, color='purple', linewidth=2)  # Outline of the chart
ax.set_yticklabels([])  # Remove radial labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=12, color='black')

# Style adjustments to make it look minimalist
ax.spines['polar'].set_visible(False)  # Hide the frame
ax.grid(linewidth=0.5, linestyle='-', color='black', alpha=0.3)  # Lighter grid lines

# Title
plt.title('AI in Financial Services Risk and Impact Assessment', fontsize=14, color='black', va='bottom')

# Add full citations as text on the chart with title and author
citation_text = ("Radar Chart")

# Add citations at the bottom of the chart, make sure they fit into multiple lines
plt.figtext(0.5, 0.05, citation_text, wrap=True, horizontalalignment='center', fontsize=10, color='black')

# Save the chart as a PNG file
file_path = 'ai_in_financial_services_risk_assessment_radar_with_creative_axes.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the chart
plt.show()

file_path

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the sets for the Venn diagram
venn_data = {
    '100': 10,  # Only in AI Adoption
    '010': 15,  # Only in Risk Management
    '001': 12,  # Only in Innovation
    '110': 5,   # In AI Adoption and Risk Management
    '101': 8,   # In AI Adoption and Innovation
    '011': 7,   # In Risk Management and Innovation
    '111': 3    # In all three: AI Adoption, Risk Management, and Innovation
}

# Create the Venn diagram
plt.figure(figsize=(6, 6))
venn = venn3(subsets=venn_data, set_labels=('AI Adoption', 'Risk Management', 'Innovation'))

# Customize the diagram with labels and title
plt.title("Venn Diagram: AI in Finance", fontsize=14, color='black')

# Save the diagram as an image
plt.savefig('ai_finance_venn_diagram.png', dpi=300, bbox_inches='tight')

# Show the diagram
plt.show()

# %%
#!pip install matplotlib_venn

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the sets for the Venn diagram
venn_data = {
    '100': 10,  # Only in AI Adoption
    '010': 15,  # Only in Risk Management
    '001': 12,  # Only in Innovation
    '110': 5,   # In AI Adoption and Risk Management
    '101': 8,   # In AI Adoption and Innovation
    '011': 7,   # In Risk Management and Innovation
    '111': 3    # In all three: AI Adoption, Risk Management, and Innovation
}

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn = venn3(subsets=venn_data, set_labels=('AI Adoption', 'Risk Management', 'Innovation'))

# Add annotations to describe each region
venn.get_label_by_id('100').set_text('10: Only in AI Adoption')
venn.get_label_by_id('010').set_text('15: Only in Risk Management')
venn.get_label_by_id('001').set_text('12: Only in Innovation')
venn.get_label_by_id('110').set_text('5: AI Adoption & Risk Management')
venn.get_label_by_id('101').set_text('8: AI Adoption & Innovation')
venn.get_label_by_id('011').set_text('7: Risk Management & Innovation')
venn.get_label_by_id('111').set_text('3: All Three')

# Title and subtitle to explain the diagram
plt.text(-0.9, 1.2, "Venn Diagram: AI in Finance", fontsize=16, fontweight='bold', color='black')
plt.text(-0.9, 1.05, "This diagram shows the intersection of three key areas in AI adoption within finance:\n"
                     "- AI Adoption\n"
                     "- Risk Management\n"
                     "- Innovation", fontsize=12, color='black')

# Save the diagram as an image
file_path = 'ai_finance_venn_diagram_explained.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the diagram
plt.show()

# Output file path for download
file_path

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the sets for the Venn diagram
venn_data = {
    '100': 10,  # Only in AI Adoption
    '010': 15,  # Only in Risk Management
    '001': 12,  # Only in Innovation
    '110': 5,   # In AI Adoption and Risk Management
    '101': 8,   # In AI Adoption and Innovation
    '011': 7,   # In Risk Management and Innovation
    '111': 3    # In all three: AI Adoption, Risk Management, and Innovation
}

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn = venn3(subsets=venn_data, set_labels=('AI Adoption', 'Risk Management', 'Innovation'))

# Add annotations to describe each region and adjust positions
venn.get_label_by_id('100').set_text('10: Only in AI Adoption')
venn.get_label_by_id('010').set_text('15: Only in Risk Management')
venn.get_label_by_id('001').set_text('12: Only in Innovation')
venn.get_label_by_id('110').set_text('5: AI Adoption & Risk Management')
venn.get_label_by_id('101').set_text('8: AI Adoption & Innovation')
venn.get_label_by_id('011').set_text('7: Risk Management & Innovation')
venn.get_label_by_id('111').set_text('3: All Three')

# Move the labels to avoid overlap
venn.get_label_by_id('100').set_position((-0.6, 0.6))  # Move "Only in AI Adoption" up and left
venn.get_label_by_id('010').set_position((0.6, 0.6))   # Move "Only in Risk Management" up and right
venn.get_label_by_id('001').set_position((0, -0.6))    # Move "Only in Innovation" down

# Move the overlapping labels to avoid collisions
venn.get_label_by_id('110').set_position((-0.6, 0))    # Move "AI Adoption & Risk Management"
venn.get_label_by_id('101').set_position((0.6, 0))     # Move "AI Adoption & Innovation"
venn.get_label_by_id('011').set_position((0, 0.6))     # Move "Risk Management & Innovation"

# Title and subtitle to explain the diagram
plt.text(-0.9, 1.2, "Venn Diagram: AI in Finance", fontsize=16, fontweight='bold', color='black')
plt.text(-0.9, 1.05, "This diagram shows the intersection of three key areas in AI adoption within finance:\n"
                     "- AI Adoption\n"
                     "- Risk Management\n"
                     "- Innovation", fontsize=12, color='black')

# Save the diagram as an image
file_path = 'ai_finance_venn_diagram_adjusted.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the diagram
plt.show()

# Output file path for download
file_path

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the sets for the Venn diagram with new axes and values
venn_data = {
    '100': 6,  # Only Data Privacy
    '010': 8,  # Only Security
    '001': 5,  # Only Regulatory Compliance
    '110': 4,  # Data Privacy & Security
    '101': 3,  # Data Privacy & Regulatory Compliance
    '011': 2,  # Security & Regulatory Compliance
    '111': 1    # All three: Data Privacy, Security, and Regulatory Compliance
}

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn = venn3(subsets=venn_data, set_labels=('Data Privacy', 'Security', 'Regulatory Compliance'))

# Add annotations to describe each region with creative text
venn.get_label_by_id('100').set_text('6: Only Data Privacy')
venn.get_label_by_id('010').set_text('8: Only Security')
venn.get_label_by_id('001').set_text('5: Only Regulatory Compliance')
venn.get_label_by_id('110').set_text('4: Data Privacy & Security')
venn.get_label_by_id('101').set_text('3: Data Privacy & Regulatory Compliance')
venn.get_label_by_id('011').set_text('2: Security & Regulatory Compliance')
venn.get_label_by_id('111').set_text('1: All Three')

# Move the labels creatively to avoid overlap
venn.get_label_by_id('100').set_position((-0.7, 0.7))  # Move "Only Data Privacy" up and left
venn.get_label_by_id('010').set_position((0.7, 0.7))   # Move "Only Security" up and right
venn.get_label_by_id('001').set_position((0, -0.7))    # Move "Only Regulatory Compliance" down

# Adjust the overlapping labels creatively
venn.get_label_by_id('110').set_position((-0.7, 0))    # Move "Data Privacy & Security"
venn.get_label_by_id('101').set_position((0.7, 0))     # Move "Data Privacy & Regulatory Compliance"
venn.get_label_by_id('011').set_position((0, 0.7))     # Move "Security & Regulatory Compliance"

# Add a creative title and some context for the diagram
plt.text(-1, 1.2, "Venn Diagram: AI Risk Management Dimensions", fontsize=16, fontweight='bold', color='black')
plt.text(-1, 1.05, "Exploring intersections between key dimensions in AI governance and risk:\n"
                     "- Data Privacy\n"
                     "- Security\n"
                     "- Regulatory Compliance", fontsize=12, color='black')

# Save the diagram as an image
file_path = 'ai_risk_management_venn_diagram.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the diagram
plt.show()

# Output file path for download
file_path

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the sets for the Venn diagram with new axes and values
venn_data = {
    '100': 6,  # Only Data Privacy
    '010': 8,  # Only Security
    '001': 5,  # Only Regulatory Compliance
    '110': 4,  # Data Privacy & Security
    '101': 3,  # Data Privacy & Regulatory Compliance
    '011': 2,  # Security & Regulatory Compliance
    '111': 1    # All three: Data Privacy, Security, and Regulatory Compliance
}

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn = venn3(subsets=venn_data, set_labels=('Data Privacy', 'Security', 'Regulatory Compliance'))

# Add annotations to describe each region with creative text
venn.get_label_by_id('100').set_text('6: Only Data Privacy')
venn.get_label_by_id('010').set_text('8: Only Security')
venn.get_label_by_id('001').set_text('5: Only Regulatory Compliance')
venn.get_label_by_id('110').set_text('4: Data Privacy & Security')
venn.get_label_by_id('101').set_text('3: Data Privacy & Regulatory Compliance')
venn.get_label_by_id('011').set_text('2: Security & Regulatory Compliance')
venn.get_label_by_id('111').set_text('1: All Three')

# Move the labels creatively to avoid overlap
venn.get_label_by_id('100').set_position((-0.7, 0.7))  # Move "Only Data Privacy" up and left
venn.get_label_by_id('010').set_position((0.7, 0.7))   # Move "Only Security" up and right
venn.get_label_by_id('001').set_position((0, -0.9))    # Move "Only Regulatory Compliance" down further

# Adjust the overlapping labels creatively
venn.get_label_by_id('110').set_position((-0.7, 0))    # Move "Data Privacy & Security"
venn.get_label_by_id('101').set_position((0.7, 0))     # Move "Data Privacy & Regulatory Compliance"
venn.get_label_by_id('011').set_position((0, 0.7))     # Move "Security & Regulatory Compliance"

# Add a creative title and some context for the diagram
plt.text(-1, 1.2, "Venn Diagram: AI Risk Management Dimensions", fontsize=16, fontweight='bold', color='black')
plt.text(-1, 1.05, "Exploring intersections between key dimensions in AI governance and risk:\n"
                     "- Data Privacy\n"
                     "- Security\n"
                     "- Regulatory Compliance", fontsize=12, color='black')

# Save the diagram as an image
file_path = 'ai_risk_management_venn_diagram_updated.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the diagram
plt.show()

# Output file path for download
file_path

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the sets for the Venn diagram with new axes and values
venn_data = {
    '100': 6,  # Only Data Privacy
    '010': 8,  # Only Security
    '001': 5,  # Only Regulatory Compliance
    '110': 4,  # Data Privacy & Security
    '101': 3,  # Data Privacy & Regulatory Compliance
    '011': 2,  # Security & Regulatory Compliance
    '111': 1    # All three: Data Privacy, Security, and Regulatory Compliance
}

# Number of papers for each area (replace these with your actual data)
papers_data = {
    '100': 2,  # Only Data Privacy
    '010': 3,  # Only Security
    '001': 1,  # Only Regulatory Compliance
    '110': 2,  # Data Privacy & Security
    '101': 1,  # Data Privacy & Regulatory Compliance
    '011': 1,  # Security & Regulatory Compliance
    '111': 1   # All three
}

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn = venn3(subsets=venn_data, set_labels=('Data Privacy', 'Security', 'Regulatory Compliance'))

# Add annotations to describe each region with creative text
venn.get_label_by_id('100').set_text(f"6: Only Data Privacy\nPapers: {papers_data['100']}")
venn.get_label_by_id('010').set_text(f"8: Only Security\nPapers: {papers_data['010']}")
venn.get_label_by_id('001').set_text(f"5: Only Regulatory Compliance\nPapers: {papers_data['001']}")
venn.get_label_by_id('110').set_text(f"4: Data Privacy & Security\nPapers: {papers_data['110']}")
venn.get_label_by_id('101').set_text(f"3: Data Privacy & Regulatory Compliance\nPapers: {papers_data['101']}")
venn.get_label_by_id('011').set_text(f"2: Security & Regulatory Compliance\nPapers: {papers_data['011']}")
venn.get_label_by_id('111').set_text(f"1: All Three\nPapers: {papers_data['111']}")

# Move the labels creatively to avoid overlap
venn.get_label_by_id('100').set_position((-0.7, 0.7))  # Move "Only Data Privacy" up and left
venn.get_label_by_id('010').set_position((0.7, 0.7))   # Move "Only Security" up and right
venn.get_label_by_id('001').set_position((0, -0.9))    # Move "Only Regulatory Compliance" down further

# Adjust the overlapping labels creatively
venn.get_label_by_id('110').set_position((-0.7, 0))    # Move "Data Privacy & Security"
venn.get_label_by_id('101').set_position((0.7, 0))     # Move "Data Privacy & Regulatory Compliance"
venn.get_label_by_id('011').set_position((0, 0.7))     # Move "Security & Regulatory Compliance"

# Add a creative title and some context for the diagram
plt.text(-1, 1.2, "Venn Diagram: AI Risk Management Dimensions", fontsize=16, fontweight='bold', color='black')
plt.text(-1, 1.05, "Exploring intersections between key dimensions in AI governance and risk:\n"
                     "- Data Privacy\n"
                     "- Security\n"
                     "- Regulatory Compliance", fontsize=12, color='black')

# Save the diagram as an image
file_path = 'ai_risk_management_venn_diagram_with_papers.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the diagram
plt.show()

# Output file path for download
file_path

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Define the sets for the Venn diagram
venn_data = {
    '100': 10,  # Only in AI Adoption
    '010': 15,  # Only in Risk Management
    '001': 12,  # Only in Innovation
    '110': 5,   # In AI Adoption and Risk Management
    '101': 8,   # In AI Adoption and Innovation
    '011': 7,   # In Risk Management and Innovation
    '111': 3    # In all three: AI Adoption, Risk Management, and Innovation
}

# Define the number of papers associated with each section
papers_data = {
    '100': 4,  # Papers in AI Adoption
    '010': 5,  # Papers in Risk Management
    '001': 3,  # Papers in Innovation
    '110': 2,  # Papers in AI Adoption & Risk Management
    '101': 2,  # Papers in AI Adoption & Innovation
    '011': 1,  # Papers in Risk Management & Innovation
    '111': 1   # Papers in All Three
}

# Create the Venn diagram
plt.figure(figsize=(8, 8))
venn = venn3(subsets=venn_data, set_labels=('AI Adoption', 'Risk Management', 'Innovation'))

# Add annotations with paper counts and region sizes
venn.get_label_by_id('100').set_text(f"10: Only in AI Adoption\nPapers: {papers_data['100']}")
venn.get_label_by_id('010').set_text(f"15: Only in Risk Management\nPapers: {papers_data['010']}")
venn.get_label_by_id('001').set_text(f"12: Only in Innovation\nPapers: {papers_data['001']}")
venn.get_label_by_id('110').set_text(f"5: AI Adoption & Risk Management\nPapers: {papers_data['110']}")
venn.get_label_by_id('101').set_text(f"8: AI Adoption & Innovation\nPapers: {papers_data['101']}")
venn.get_label_by_id('011').set_text(f"7: Risk Management & Innovation\nPapers: {papers_data['011']}")
venn.get_label_by_id('111').set_text(f"3: All Three\nPapers: {papers_data['111']}")

# Adjust label positions to avoid overlap
venn.get_label_by_id('100').set_position((-0.6, 0.6))  # Move "Only in AI Adoption" up and left
venn.get_label_by_id('010').set_position((0.6, 0.6))   # Move "Only in Risk Management" up and right
venn.get_label_by_id('001').set_position((0, -0.6))    # Move "Only in Innovation" down

# Move the overlapping labels to avoid collisions
venn.get_label_by_id('110').set_position((-0.6, 0))    # Move "AI Adoption & Risk Management"
venn.get_label_by_id('101').set_position((0.6, 0))     # Move "AI Adoption & Innovation"
venn.get_label_by_id('011').set_position((0, 0.6))     # Move "Risk Management & Innovation"

# Title and subtitle to explain the diagram
plt.text(-0.9, 1.2, "Venn Diagram: AI in Finance", fontsize=16, fontweight='bold', color='black')
plt.text(-0.9, 1.05, "This diagram shows the intersection of three key areas in AI adoption within finance:\n"
                     "- AI Adoption\n"
                     "- Risk Management\n"
                     "- Innovation", fontsize=12, color='black')

# Save the diagram as an image
file_path = 'ai_finance_venn_diagram_with_papers.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the diagram
plt.show()

# Output file path for download
file_path

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the paper data for the heatmap
paper_counts = np.array([
    [4, 2, 2],  # AI Adoption, Risk Management, Innovation
    [2, 1, 2],  # AI Adoption & Risk Management, AI Adoption & Innovation, Risk Management & Innovation
    [1, 3, 1]   # All three areas intersection
])

# Define the labels for the heatmap
labels = ['AI Adoption', 'Risk Management', 'Innovation']

# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(paper_counts, annot=True, fmt="d", cmap="YlGnBu", xticklabels=labels, yticklabels=labels, cbar_kws={'label': 'Number of Papers'})

# Title
plt.title('Heatmap: Paper Distribution in AI Adoption, Risk Management, and Innovation', fontsize=16, fontweight='bold')

# Save the heatmap as an image
file_path = 'ai_finance_paper_heatmap.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the heatmap
plt.show()

# Output file path for download
file_path

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the paper data for the heatmap with new axes and variation
paper_counts = np.array([
    [3, 6, 4],  # Only AI Adoption, Only Risk Management, Only Innovation
    [5, 8, 6],  # AI Adoption & Risk Management, AI Adoption & Innovation, Risk Management & Innovation
    [4, 3, 5]   # All three intersections
])

# Define the new labels for this variation
labels = ['AI Adoption', 'Risk Management', 'Innovation']

# Create the heatmap with different axes and styling
plt.figure(figsize=(8, 6))
sns.heatmap(paper_counts, annot=True, fmt="d", cmap="coolwarm", xticklabels=labels, yticklabels=labels, cbar_kws={'label': 'Number of Papers'})

# Title
plt.title('Variation Heatmap: Paper Distribution in Key Areas of AI Adoption in Finance', fontsize=16, fontweight='bold')

# Save the heatmap as an image
file_path = 'ai_finance_paper_heatmap_v2.png'
plt.savefig(file_path, dpi=300, bbox_inches='tight')

# Show the heatmap
plt.show()

# Output file path for download
file_path

# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout

# Create a directed graph to represent the method tree
G = nx.DiGraph()

# Define the nodes (methods or steps) and their relationships
G.add_edges_from([
    ('AI Adoption', 'Assess Data Availability'),
    ('AI Adoption', 'Evaluate Technical Feasibility'),
    ('AI Adoption', 'Check Regulatory Compliance'),
    ('Risk Management', 'Analyze Risk Factors'),
    ('Risk Management', 'Assess Model Robustness'),
    ('Innovation', 'Investigate New Technologies'),
    ('Innovation', 'Monitor Market Trends'),
    ('Assess Data Availability', 'Data Collection'),
    ('Evaluate Technical Feasibility', 'Assess Computational Resources'),
    ('Check Regulatory Compliance', 'Review Legal Regulations'),
    ('Analyze Risk Factors', 'Market Risks'),
    ('Assess Model Robustness', 'Test Against Edge Cases'),
    ('Investigate New Technologies', 'AI Models'),
    ('Monitor Market Trends', 'Competitive Analysis')
])

# Use graphviz_layout for a hierarchical layout
pos = graphviz_layout(G, prog='dot')  # Using 'dot' for hierarchical layout

# Draw the method tree with adjusted positions
plt.figure(figsize=(12, 10))
nx.draw(G, pos, with_labels=True, node_size=5000, node_color='skyblue', font_size=10, font_weight='bold', arrows=True, width=2, edge_color='gray')

# Title and subtitle
plt.title('Method Tree: AI Adoption, Risk Management, and Innovation', fontsize=16, fontweight='bold')

# Show the tree without overlaps
plt.tight_layout()
plt.show()

# %%
#!pip install pygraphviz

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Add simplified nodes
dot.node('A', 'AI Adoption')
dot.node('B', 'Risk Management')
dot.node('C', 'Innovation')

# Add simplified edges between the nodes
dot.edge('A', 'B', label='Impacts')
dot.edge('A', 'C', label='Drives')
dot.edge('B', 'C', label='Influences')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_simple.png'
dot.render(file_path, format='png', cleanup=True)

# Output the file path for download
file_path

# %%
#!pip install graphviz

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Add simplified nodes
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)')
dot.node('C', 'Innovation\n(Martinez, 2022)')

# Add simplified edges between the nodes with citation labels
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)')
dot.edge('A', 'C', label='Drives (Martinez, 2022)')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_with_citations.png'
dot.render(file_path, format='png', cleanup=True)

# Output the file path for download
file_path

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Adjust node size, font size, and colors to make it more visually appealing
dot.attr(dpi='300')  # Set higher DPI for better resolution

# Add nodes with customized sizes and fonts
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('C', 'Innovation\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightyellow')

# Add edges with labels for citations, adjusting label font size
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('A', 'C', label='Drives (Martinez, 2022)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)', fontsize='12', fontname='Helvetica')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_with_citations_large.png'
dot.render(file_path, format='png', cleanup=True)

# Output the file path for download
file_path

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Adjust node size, font size, and colors to make it more visually appealing
dot.attr(dpi='300')  # Set higher DPI for better resolution

# Add nodes with customized sizes and fonts
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('C', 'Innovation\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightyellow')
dot.node('D', 'Prompt Engineering\n(Paup, Rebouh, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcoral')
dot.node('E', 'Generative AI Risks\n(Boukherouaa, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('F', 'Zero-shot Learning\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightpink')
dot.node('G', 'Financial AI Applications\n(Paup, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue')
dot.node('H', 'AI Challenges in Finance\n(Khan, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgray')
dot.node('I', 'AI and Financial Ethics\n(Smith, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightviolet')
dot.node('J', 'AI for Risk Management\n(Wang, Li, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('K', 'AI in Financial Decision Making\n(Liu, Zhang, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcyan')

# Add edges with labels for citations, adjusting label font size
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('A', 'C', label='Drives (Martinez, 2022)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'E', label='AI Risk Considerations (Boukherouaa, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('C', 'D', label='Prompt Engineering (Paup, Rebouh, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('D', 'G', label='Applications (Paup, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('E', 'F', label='Zero-shot Learning (Martinez, 2022)', fontsize='12', fontname='Helvetica')

# Additional connections for new papers
dot.edge('H', 'A', label='Challenges in AI Adoption (Khan, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('I', 'B', label='Ethical Issues in AI (Smith, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('J', 'B', label='AI and Risk Management (Wang, Li, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('K', 'B', label='AI in Financial Decision Making (Liu, Zhang, 2023)', fontsize='12', fontname='Helvetica')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_with_more_papers_v2.png'
dot.render(file_path, format='png', cleanup=True)

# Output the file path for download
file_path

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Adjust node size, font size, and colors to make it more visually appealing
dot.attr(dpi='300')  # Set higher DPI for better resolution

# Add nodes with customized sizes, fonts, and non-black background colors
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('C', 'Innovation\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightyellow')
dot.node('D', 'Prompt Engineering\n(Paup, Rebouh, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcoral')
dot.node('E', 'Generative AI Risks\n(Boukherouaa, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('F', 'Zero-shot Learning\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightpink')
dot.node('G', 'Financial AI Applications\n(Paup, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue')
dot.node('H', 'AI Challenges in Finance\n(Khan, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgray')
dot.node('I', 'AI and Financial Ethics\n(Smith, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightviolet')
dot.node('J', 'AI for Risk Management\n(Wang, Li, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('K', 'AI in Financial Decision Making\n(Liu, Zhang, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcyan')

# Add edges with labels for citations, adjusting label font size
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('A', 'C', label='Drives (Martinez, 2022)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'E', label='AI Risk Considerations (Boukherouaa, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('C', 'D', label='Prompt Engineering (Paup, Rebouh, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('D', 'G', label='Applications (Paup, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('E', 'F', label='Zero-shot Learning (Martinez, 2022)', fontsize='12', fontname='Helvetica')

# Additional connections for new papers
dot.edge('H', 'A', label='Challenges in AI Adoption (Khan, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('I', 'B', label='Ethical Issues in AI (Smith, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('J', 'B', label='AI and Risk Management (Wang, Li, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('K', 'B', label='AI in Financial Decision Making (Liu, Zhang, 2023)', fontsize='12', fontname='Helvetica')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_with_fixed_colors.png'
dot.render(file_path, format='png', cleanup=True)

# Output the file path for download
file_path

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Adjust node size, font size, and colors to make it more visually appealing
dot.attr(dpi='300')  # Set higher DPI for better resolution

# Add nodes with customized sizes, fonts, and non-black background colors
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('C', 'Innovation\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightyellow')
dot.node('D', 'Prompt Engineering\n(Paup, Rebouh, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcoral')
dot.node('E', 'Generative AI Risks\n(Boukherouaa, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('F', 'Zero-shot Learning\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightpink')
dot.node('G', 'Financial AI Applications\n(Paup, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue')
dot.node('H', 'AI Challenges in Finance\n(Khan, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgray')
dot.node('I', 'AI and Financial Ethics\n(Smith, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightviolet')
dot.node('J', 'AI for Risk Management\n(Wang, Li, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen')
dot.node('K', 'AI in Financial Decision Making\n(Liu, Zhang, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcyan')

# Add edges with labels for citations, adjusting label font size
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('A', 'C', label='Drives (Martinez, 2022)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'E', label='AI Risk Considerations (Boukherouaa, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('C', 'D', label='Prompt Engineering (Paup, Rebouh, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('D', 'G', label='Applications (Paup, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('E', 'F', label='Zero-shot Learning (Martinez, 2022)', fontsize='12', fontname='Helvetica')

# Additional connections for new papers
dot.edge('H', 'A', label='Challenges in AI Adoption (Khan, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('I', 'B', label='Ethical Issues in AI (Smith, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('J', 'B', label='AI and Risk Management (Wang, Li, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('K', 'B', label='AI in Financial Decision Making (Liu, Zhang, 2023)', fontsize='12', fontname='Helvetica')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_with_corrected_colors.png'
dot.render(file_path, format='png', cleanup=True)

# Output the file path for download
file_path

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Adjust node size, font size, and colors to make it more visually appealing
dot.attr(dpi='300')  # Set higher DPI for better resolution

# Add nodes with customized sizes, fonts, and non-black background colors
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue', color='black')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('C', 'Innovation\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightyellow', color='black')
dot.node('D', 'Prompt Engineering\n(Paup, Rebouh, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcoral', color='black')
dot.node('E', 'Generative AI Risks\n(Boukherouaa, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('F', 'Zero-shot Learning\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightpink', color='black')
dot.node('G', 'Financial AI Applications\n(Paup, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue', color='black')
dot.node('H', 'AI Challenges in Finance\n(Khan, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgray', color='black')
dot.node('I', 'AI and Financial Ethics\n(Smith, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightviolet', color='black')
dot.node('J', 'AI for Risk Management\n(Wang, Li, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('K', 'AI in Financial Decision Making\n(Liu, Zhang, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcyan', color='black')

# Add edges with labels for citations, adjusting label font size
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('A', 'C', label='Drives (Martinez, 2022)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'E', label='AI Risk Considerations (Boukherouaa, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('C', 'D', label='Prompt Engineering (Paup, Rebouh, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('D', 'G', label='Applications (Paup, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('E', 'F', label='Zero-shot Learning (Martinez, 2022)', fontsize='12', fontname='Helvetica')

# Additional connections for new papers
dot.edge('H', 'A', label='Challenges in AI Adoption (Khan, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('I', 'B', label='Ethical Issues in AI (Smith, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('J', 'B', label='AI and Risk Management (Wang, Li, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('K', 'B', label='AI in Financial Decision Making (Liu, Zhang, 2023)', fontsize='12', fontname='Helvetica')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_with_fixes.png'
dot.render(file_path, format='png', cleanup=True)

# Output the file path for download
file_path

# %%
from graphviz import Digraph
from IPython.display import Image, display
import os

# Ensure the directory exists
output_dir = './'
os.makedirs(output_dir, exist_ok=True)

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Adjust node size, font size, and colors to make it more visually appealing
dot.attr(dpi='300')  # Set higher DPI for better resolution

# Add nodes with customized sizes, fonts, and non-black background colors
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue', color='black')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('C', 'Innovation\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightyellow', color='black')
dot.node('D', 'Prompt Engineering\n(Paup, Rebouh, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcoral', color='black')
dot.node('E', 'Generative AI Risks\n(Boukherouaa, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('F', 'Zero-shot Learning\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightpink', color='black')
dot.node('G', 'Financial AI Applications\n(Paup, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue', color='black')
dot.node('H', 'AI Challenges in Finance\n(Khan, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgray', color='black')
dot.node('I', 'AI and Financial Ethics\n(Smith, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightviolet', color='black')
dot.node('J', 'AI for Risk Management\n(Wang, Li, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('K', 'AI in Financial Decision Making\n(Liu, Zhang, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcyan', color='black')

# Add edges with labels for citations, adjusting label font size
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('A', 'C', label='Drives (Martinez, 2022)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'E', label='AI Risk Considerations (Boukherouaa, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('C', 'D', label='Prompt Engineering (Paup, Rebouh, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('D', 'G', label='Applications (Paup, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('E', 'F', label='Zero-shot Learning (Martinez, 2022)', fontsize='12', fontname='Helvetica')

# Additional connections for new papers
dot.edge('H', 'A', label='Challenges in AI Adoption (Khan, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('I', 'B', label='Ethical Issues in AI (Smith, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('J', 'B', label='AI and Risk Management (Wang, Li, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('K', 'B', label='AI in Financial Decision Making (Liu, Zhang, 2023)', fontsize='12', fontname='Helvetica')

# Render the graph to a file in the output_images directory (e.g., PNG)
file_path = os.path.join(output_dir, 'ai_finance_method_tree_with_fixes.png')
dot.render(file_path, format='png', cleanup=True)

# Display the rendered image
display(Image(file_path))
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# ...

# %%
from graphviz import Digraph
from IPython.display import Image, display

# Create a new directed graph
dot = Digraph(comment='AI in Finance')

# Adjust node size, font size, and colors to make it more visually appealing
dot.attr(dpi='300')  # Set higher DPI for better resolution

# Add nodes with customized sizes, fonts, and non-black background colors
dot.node('A', 'AI Adoption\n(Boukherouaa, Shabsigh, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue', color='black')
dot.node('B', 'Risk Management\n(Khan, Umer, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('C', 'Innovation\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightyellow', color='black')
dot.node('D', 'Prompt Engineering\n(Paup, Rebouh, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcoral', color='black')
dot.node('E', 'Generative AI Risks\n(Boukherouaa, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('F', 'Zero-shot Learning\n(Martinez, 2022)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightpink', color='black')
dot.node('G', 'Financial AI Applications\n(Paup, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightblue', color='black')
dot.node('H', 'AI Challenges in Finance\n(Khan, 2024)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgray', color='black')
dot.node('I', 'AI and Financial Ethics\n(Smith, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightviolet', color='black')
dot.node('J', 'AI for Risk Management\n(Wang, Li, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightgreen', color='black')
dot.node('K', 'AI in Financial Decision Making\n(Liu, Zhang, 2023)', width='2.5', height='1', fontsize='14', style='filled', fillcolor='lightcyan', color='black')

# Add edges with labels for citations, adjusting label font size
dot.edge('A', 'B', label='Impacts (Boukherouaa, Shabsigh, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('A', 'C', label='Drives (Martinez, 2022)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'C', label='Influences (Khan, Umer, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('B', 'E', label='AI Risk Considerations (Boukherouaa, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('C', 'D', label='Prompt Engineering (Paup, Rebouh, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('D', 'G', label='Applications (Paup, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('E', 'F', label='Zero-shot Learning (Martinez, 2022)', fontsize='12', fontname='Helvetica')

# Additional connections for new papers
dot.edge('H', 'A', label='Challenges in AI Adoption (Khan, 2024)', fontsize='12', fontname='Helvetica')
dot.edge('I', 'B', label='Ethical Issues in AI (Smith, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('J', 'B', label='AI and Risk Management (Wang, Li, 2023)', fontsize='12', fontname='Helvetica')
dot.edge('K', 'B', label='AI in Financial Decision Making (Liu, Zhang, 2023)', fontsize='12', fontname='Helvetica')

# Render the graph to a file (e.g., PNG or PDF)
file_path = 'ai_finance_method_tree_with_fixes.png'
dot.render(file_path, format='png', cleanup=True)

# Display the rendered image
# Out:
# ...
# 'ai_finance_method_tree_with_fixes.png.png'

# %%
display(Image(file_path))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# ...
